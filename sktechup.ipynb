# %%
import numpy as np
data = np.array([[0.4181,	0.7483,	0.7856,	0.5657,	0.6666,	0.7786,	0.6029],
                 [0.4224,	0.7538,	0.7740,	0.5669,	0.6819,	0.7797,	0.6209],
                 [0.4181,	0.7483,	0.7856,	0.5657,	0.6666,	0.7786,	0.6029],
                 [0.4224,	0.7538,	0.7740,	0.5669,	0.6819,	0.7797,	0.6209],
                 [0.4224,	0.7500,	0.7633,	0.5608,	0.6765,	0.7775,	0.5776],                       
                 ])
mean_value = np.mean(data, axis=1)
print("Mean value:", mean_value)
# Out:
# Mean value: [0.65225714 0.65708571 0.65225714 0.65708571 0.64687143]

# %%
import numpy as np
data = np.array([0.4241,	0.7420,	0.7193,	0.5495,	0.6196,	0.7699,	0.6173])
mean_value = np.mean(data)
print("Mean value:", mean_value)
# Out:
# Mean value: 0.6345285714285714

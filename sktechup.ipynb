# %%
import numpy as np
data = np.array([   [0.4590,	0.7146,	0.7700,	0.7502,	0.6420,	0.7840,	0.6353],
                    [0.4514,	0.7365,	0.7838,	0.7482,	0.6868,	0.7813,	0.6498],
                    [0.4360,	0.7243,	0.7927,	0.7431,	0.6761,	0.7824,	0.5957],
                    [0.4420,	0.7239,	0.7789,	0.7454,	0.6746,	0.7856,	0.5704],
                    [0.4360,	0.7252,	0.7749,	0.7368,	0.6796,	0.7813,	0.6823],
                    [0.4352,	0.7306,	0.7749,	0.7336,	0.6788,	0.7807,	0.6643],
                    [0.4428,	0.7235,	0.7520,	0.7540,	0.6693,	0.7840,	0.6462],
                    [0.4480,	0.7289,	0.7535,	0.7558,	0.6567,	0.7818,	0.6462],
                    [0.4411,	0.7365,	0.7875,	0.7577,	0.6889,	0.7780,	0.6426],
                    [0.4454,	0.7252,	0.7875,	0.7561,	0.6759,	0.7856,	0.6570],
                    [0.4514,	0.7226,	0.7627,	0.7601,	0.6492,	0.7753,	0.6173],
                    [0.4514,	0.7277,	0.7624,	0.7597,	0.6522,	0.7813,	0.6498],
                 ])
mean_value = np.mean(data, axis=1)
print("Mean value:", mean_value)
# Out:
# Mean value: [0.6793     0.69111429 0.67861429 0.6744     0.68801429 0.68544286
#  0.68168571 0.68155714 0.69032857 0.69038571 0.67694286 0.6835    ]

# %%
import numpy as np
data = np.array([0.4598, 0.7352, 0.7771, 0.7556, 0.6708, 0.7818, 0.6317])
mean_value = np.mean(data)
print("Mean value:", mean_value)
# Out:
# Mean value: 0.6874285714285714

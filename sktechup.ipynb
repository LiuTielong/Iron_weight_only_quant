# %%
import numpy as np
data = np.array([   [0.5495,	0.7845,	0.8397,	0.8345,	0.7376,	0.8199,	0.6931],
                    [0.5614,	0.7950,	0.8229,	0.8240,	0.7380,	0.8194,	0.6606],
                    [0.5503,	0.7849,	0.8520,	0.8328,	0.7483,	0.8254,	0.7256],
                    [0.5486,	0.8005,	0.8514,	0.8305,	0.7609,	0.8243,	0.6931],
                    [0.5691,	0.8026,	0.8275,	0.8360,	0.7270,	0.8275,	0.7256],
                    [0.5614,	0.7841,	0.8517,	0.8418,	0.7390,	0.8221,	0.7076],
                    [0.5563,	0.8018,	0.8312,	0.8375,	0.7297,	0.8226,	0.6859],
                 ])
mean_value = np.mean(data, axis=1)
print("Mean value:", mean_value)
# Out:
# Mean value: [0.75125714 0.7459     0.7599     0.75847143 0.75932857 0.75824286
#  0.75214286]

# %%
import numpy as np
data = np.array([0.5683, 0.7946, 0.8538, 0.8417, 0.7471, 0.8259, 0.7112])
mean_value = np.mean(data)
print("Mean value:", mean_value)
# Out:
# Mean value: 0.7632285714285715

# %%
# Out:
# 172.0

# %%
# Out:
# 23.813953488372093

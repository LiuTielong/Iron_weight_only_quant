# %%
import numpy as np
data = np.array([[0.4317,	0.7516,	0.7771,	0.5665,	0.6708,	0.7769,	0.6317],
                 [0.3413,	0.6587,	0.5406,	0.4684,	0.3293,	0.7252,	0.5379],
                 [0.4369,	0.7504,	0.7838,	0.5610,	0.6868,	0.7775,	0.6498],
                 [0.4360,	0.7424,	0.7927,	0.5605,	0.6761,	0.7775,	0.5957],
                 [0.4156,	0.7445,	0.7789,	0.5583,	0.6746,	0.7802,	0.5704],
                 [0.3874,	0.7205,	0.7425,	0.5270,	0.6200,	0.7644,	0.6606],
                 [0.4241,	0.7420,	0.7193,	0.5495,	0.6196,	0.7699,	0.6173],
                 [0.4155,	0.7298,	0.6878,	0.5240,	0.5356,	0.7612,	0.6209],
                 [0.4326,	0.7622,	0.7942,	0.5652,	0.6796,	0.7802,	0.6390],
                 [0.4215,	0.7433,	0.7394,	0.5464,	0.6142,	0.7758,	0.6389]])
mean_value = np.mean(data, axis=1)
print("Mean value:", mean_value)
# Out:
# Mean value: [0.65804286 0.51448571 0.66374286 0.65441429 0.64607143 0.63177143
#  0.63452857 0.61068571 0.66471429 0.63992857]
